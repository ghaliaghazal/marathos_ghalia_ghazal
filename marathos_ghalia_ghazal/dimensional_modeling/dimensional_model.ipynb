# %%
fct_results = spark.sql("""
SELECT
    result_id,
    event_id,
    athlete_id,
    Athlete_country,
    Athlete_average_speed,
    Event_distance_length
FROM marathos.silver.silver_layer
""")

display(fct_results)

# %%
dim_athlete = spark.sql("""
SELECT DISTINCT
    athlete_id,
    Athlete_country
FROM marathos.silver.silver_layer
""")

display(dim_athlete)
